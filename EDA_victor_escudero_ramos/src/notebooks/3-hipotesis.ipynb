# %% [markdown]
# <h1>1 - Hipótesis:

# %% [markdown]
# <h3>El objetivo de este análisis es demostrar que el precio de un vehículo lo determiana en gran medida su potencia en caballos.

# %% [markdown]
# Observamos que las siguientes variables tienen correlación con el precio:
# * mpg_avg
# * cylindernumber
# * horsepower
# * drivewheels
# * wheelbase

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/car_price_clean.csv', index_col = 'Unnamed: 0')
df
# Out:
#                       CarName      carbody  drivewheel  fueltype  doornumber  \
# 0          alfa-romero giulia  convertible           1         0           2
# 1         alfa-romero stelvio  convertible           1         0           2
# 2    alfa-romero Quadrifoglio    hatchback           1         0           2
# 3                 audi 100 ls        sedan           0         0           4
# 4                  audi 100ls        sedan           2         0           4
# ..                        ...          ...         ...       ...         ...
# 200           volvo 145e (sw)        sedan           1         0           4
# 201               volvo 144ea        sedan           1         0           4
# 202               volvo 244dl        sedan           1         0           4
# 203                 volvo 246        sedan           1         1           4
# 204               volvo 264gl        sedan           1         0           4
#
# ...

# %% [markdown]
# <h1>2 - Comprobamos la relación entre precio y las variables con mayor correlación:

# %%
sns.set_style("darkgrid")

# %% [markdown]
# <h2> 1 - mpg_avg

# %%
sns.regplot(df['mpg_avg'], df['price'], scatter_kws={"color": "blue"}, line_kws={"color": "red"})
plt.ylim(0)
plt.show()

# %% [markdown]
# <h3> Observación:

# %% [markdown]
# Podemos observar que a menor capacidad de recorrer millas por galón, el precio aumenta

# %% [markdown]
# <h3> Conclusión:

# %% [markdown]
# Como el número de millas por galón es inversamente proporcional a la potencia en caballos, podemos deducir que la relación que tienen las millas por galón con el precio se debe a su relación directa con la potencia en caballos.

# %% [markdown]
# <h2>2 - horsepower

# %%
sns.regplot(df['horsepower'], df['price'], scatter_kws={"color": "blue"}, line_kws={"color": "green"})
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='price'>

# %% [markdown]
# <h3> Observación:

# %% [markdown]
# Podemos ver que a mayor potencia en caballos el precio aumenta dibujando una linea parecida a una regresiva polinómica.

# %% [markdown]
# <h2>3 - drivewheel

# %%
sns.violinplot(df['drivewheel'],df['price'])
# Out:
# <AxesSubplot:xlabel='drivewheel', ylabel='price'>

# %% [markdown]
# <h3> Observación:

# %% [markdown]
# La distribución con mayor rango de precios se encuentra en los coches de tracción trasera (tipo 1) siendo de rango más reducidido los de de tipo 0 y tipo 2 (traccion delantera y trancción total respectivamente)

# %% [markdown]
# <h3> Conclusión:

# %% [markdown]
# Como la distribución de precios de los vehiculos con tracción trasera (tipo 1) abarca un rango comprendido entre los más bajos y los más altos, y los otros tipos de tracción estan comprendidos entre los 10.000€ y 20.000€, no podemos concluir con que tenga relación directa con el precio del vehículo.

# %% [markdown]
# <h2>4 -  wheelbase

# %%
sns.regplot(df['wheelbase'],df['price'], scatter_kws={"color": "blue"}, line_kws={"color": "green"})
# Out:
# <AxesSubplot:xlabel='wheelbase', ylabel='price'>

# %% [markdown]
# <h3> Observación:

# %% [markdown]
# La distancia entre los ejes de los vehículos presenta una distribución dispersa.

# %% [markdown]
# <h3> Conclusión:

# %% [markdown]
# Aunque tiende a ascender el precio con el tamaño del vehículo, vemos que la distribuciñon de los precios más altos tambien se encuentran en vehiculos de menor tamaño y al contrario, la distribución de los precios bajos se encuentran en vehículos de mayor tamaño.

# %% [markdown]
# <h2> 5 - cylindernumber

# %%
sns.violinplot(df['cylindernumber'],df['price'])
# Out:
# <AxesSubplot:xlabel='cylindernumber', ylabel='price'>

# %% [markdown]
# <h3> Observación:

# %% [markdown]
# Se observa que: a mayor numero de cilindros mayor es el precio, pero hay coches con precios muy elevados con un número de cilindros menor a 12.

# %% [markdown]
# <h3> Conclusión:

# %% [markdown]
# No podemos concluir que el número de cilindros repercute en el precio del vehículo, ya que observamos una distribuciónde precios muy dispar en cada uno de ellos. Ya que, por ejemplo, un vehículo con 6 cilindros puede costar menos que uno de 4 e igual que uno de 8.

# %% [markdown]
# <h1>3 - Conclusión:

# %%
sns.regplot(df['horsepower'],df['price'], scatter_kws={"color": "blue"}, line_kws={"color": "green"})
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='price'>

# %% [markdown]
# En esta gráfica es en la única que podemos observar una correlación directa sin ningún tipo de anomalía ni distribución anormal, por lo que, con lo previamente analizado, podemos concluir que la relación más determinante es la potencia en caballos.
